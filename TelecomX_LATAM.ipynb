# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd

# Replace 'your_file.json' with the actual path to your JSON file
try:
    df = pd.read_json('/TelecomX_Data.json')
    print("Data extracted successfully!")
    display(df.head())
except FileNotFoundError:
    print("Error: your_file.json not found. Please provide the correct file path.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Data extracted successfully!
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# ...

# %%
# Define the columns containing nested dictionaries
nested_cols = ['customer', 'phone', 'internet', 'account']

# Normalize the nested columns and concatenate them with the original DataFrame
for col in nested_cols:
    df = pd.concat([df.drop(col, axis=1), pd.json_normalize(df[col])], axis=1)

print("Nested data extracted and flattened successfully!")
display(df.head())
# Out:
# Nested data extracted and flattened successfully!
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %% [markdown]
# #🔧 Transformación

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
import pandas as pd

# %%
import pandas as pd

print("Unique values in each column:")
for col in df.columns:
    print(f"\n--- {col} ---")
    print(pd.unique(df[col]))
# Out:
# Unique values in each column:
#
# --- customerID ---
# ['0002-ORFBO' '0003-MKNFE' '0004-TLHLJ' ... '9992-UJOEL' '9993-LHIEB'
#  '9995-HOTOH']
#
# --- Churn ---
# [0 1]
#
# --- gender ---
# ['Female' 'Male']
#
# --- SeniorCitizen ---
# [0 1]
#
# --- Partner ---
# [1 0]
#
# --- Dependents ---
# [1 0]
#
# --- tenure ---
# [ 9  4 13  3 71 63  7 65 54 72  5 56 34  1 45 50 23 55 26 69 37 49 66 67
#  20 43 59 12 27  2 25 29 14 35 64 39 40 11  6 30 70 57 58 16 32 33 10 21
#  61 15 44 22 24 19 47 62 46 52  8 60 48 28 41 53 68 31 36 17 18 51 38 42
#   0]
#
# --- PhoneService ---
# [1 0]
#
# --- MultipleLines ---
# [0 1]
#
# --- InternetService ---
# ['DSL' 'Fiber optic' 'No']
#
# --- OnlineSecurity ---
# [0 1]
#
# --- OnlineBackup ---
# [1 0]
#
# --- DeviceProtection ---
# [0 1]
#
# --- TechSupport ---
# [1 0]
#
# --- StreamingTV ---
# [1 0]
#
# --- StreamingMovies ---
# [0 1]
#
# --- Contract ---
# ['One year' 'Month-to-month' 'Two year']
#
# --- PaperlessBilling ---
# [1 0]
#
# ...

# %% [markdown]
# Let's convert the `Charges.Total` column to a numerical type and handle any potential errors during conversion.

# %%
# Convert 'Charges.Total' to numeric, coercing errors to NaN
df['Charges.Total'] = pd.to_numeric(df['Charges.Total'], errors='coerce')

# Identify rows where coercion resulted in NaN
errored_charges_df = df[df['Charges.Total'].isnull()].copy()

# Store the original Charges.Total values for these rows
errored_charges_df['Original_Charges.Total'] = df.loc[errored_charges_df.index, 'Charges.Total']

# Display the rows with errors and their original values
print("Rows with errors during Charges.Total conversion:")
display(errored_charges_df[['customerID', 'Original_Charges.Total']])

# Check for missing values created by the coercion
print("\nMissing values in Charges.Total after conversion:")
print(df['Charges.Total'].isnull().sum())

# Display the data types to confirm the change
print("\nData types after converting Charges.Total:")
df.info()
# Out:
# Rows with errors during Charges.Total conversion:
#       customerID  Original_Charges.Total
# 975   1371-DWPAZ                     NaN
# 1775  2520-SGTTA                     NaN
# 1955  2775-SEFEE                     NaN
# 2075  2923-ARZLG                     NaN
# 2232  3115-CZMZD                     NaN
# 2308  3213-VVOLG                     NaN
# 2930  4075-WKNIU                     NaN
# 3134  4367-NUYAO                     NaN
# 3203  4472-LVYGI                     NaN
# 4169  5709-LVOEQ                     NaN
# 5599  7644-OMVMY                     NaN
# Missing values in Charges.Total after conversion:
# 11
#
# Data types after converting Charges.Total:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
# ...

# %% [markdown]
# Now, let's check the unique values in the remaining object columns to identify inconsistencies.

# %%
errored_charges_index_list = errored_charges_df.index.tolist()
print("Index of errored_charges_df as a list:")
print(errored_charges_index_list)
# Out:
# Index of errored_charges_df as a list:
# [975, 1775, 1955, 2075, 2232, 2308, 2930, 3134, 3203, 4169, 5599]

# %%
# Replace the NaN values in 'Charges.Total' with the corresponding 'Charges.Monthly' values
for index in errored_charges_index_list:
    df.loc[index, 'Charges.Total'] = df.loc[index, 'Charges.Monthly']

# Verify that there are no more missing values in 'Charges.Total'
print("Missing values in Charges.Total after imputation:")
print(df['Charges.Total'].isnull().sum())

# Display the updated rows to confirm the changes
print("\nUpdated rows:")
display(df.loc[errored_charges_index_list, ['Charges.Monthly', 'Charges.Total']])
# Out:
# Missing values in Charges.Total after imputation:
# 0
#
# Updated rows:
#       Charges.Monthly  Charges.Total
# 975             56.05          56.05
# 1775            20.00          20.00
# 1955            61.90          61.90
# 2075            19.70          19.70
# 2232            20.25          20.25
# 2308            25.35          25.35
# 2930            73.35          73.35
# 3134            25.75          25.75
# 3203            52.55          52.55
# 4169            80.85          80.85
# 5599            19.85          19.85

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
# Get the value counts for the 'Churn' column
print("Value counts for the 'Churn' column:")
print(df['Churn'].value_counts())

# Get the value counts as a percentage
print("\nValue counts for the 'Churn' column (percentage):")
print(df['Churn'].value_counts(normalize=True) * 100)
# Out:
# Value counts for the 'Churn' column:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64
#
# Value counts for the 'Churn' column (percentage):
# Churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
# Identify rows where Churn is an empty string
churn_empty_rows = df[df['Churn'] == ""].copy()

# Remove rows with empty Churn values from the original DataFrame
df = df[df['Churn'] != ""].copy()

print("Rows with empty Churn values removed and stored in 'churn_empty_rows'.")
print("\nOriginal DataFrame shape after removal:")
print(df.shape)
print("\nRows with empty Churn values:")
display(churn_empty_rows.head())
# Out:
# Rows with empty Churn values removed and stored in 'churn_empty_rows'.
#
# Original DataFrame shape after removal:
# (7043, 22)
#
# Rows with empty Churn values:
#      customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 30   0047-ZHDTW        Female              0      No         No      11
# 75   0120-YZLQA          Male              0      No         No      71
# 96   0154-QYHJU          Male              0      No         No      29
# 98   0162-RZGMZ        Female              1      No         No       5
# 175  0274-VVQOQ          Male              1     Yes         No      65
#
#     PhoneService MultipleLines InternetService  ...     DeviceProtection  \
# 30           Yes           Yes     Fiber optic  ...                   No
# 75           Yes            No              No  ...  No internet service
# 96           Yes            No             DSL  ...                   No
# 98           Yes            No             DSL  ...                   No
# ...

# %%
# Create the 'Cuentas_Diarias' column by dividing monthly charges by 30
df['Cuentas_Diarias'] = df['Charges.Monthly'] / 30

print("New 'Cuentas_Diarias' column created successfully!")
display(df[['Charges.Monthly', 'Cuentas_Diarias']].head())
# Out:
# New 'Cuentas_Diarias' column created successfully!
#    Charges.Monthly  Cuentas_Diarias
# 0             65.6         2.186667
# 1             59.9         1.996667
# 2             73.9         2.463333
# 3             98.0         3.266667
# 4             83.9         2.796667

# %%
# Replace 'No phone service' with 'No' in 'MultipleLines'
df['MultipleLines'] = df['MultipleLines'].replace('No phone service', 'No')

# Replace 'No internet service' with 'No' in internet-related columns
internet_cols_to_clean = ['OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies']
for col in internet_cols_to_clean:
    df[col] = df[col].replace('No internet service', 'No')

print("Values replaced successfully.")

# Verify the changes by checking unique values in the modified columns
print("\nUnique values in modified columns:")
columns_to_verify = ['MultipleLines'] + internet_cols_to_clean
for col in columns_to_verify:
    print(f"\n--- {col} ---")
    print(df[col].unique())
# Out:
# Values replaced successfully.
#
# Unique values in modified columns:
#
# --- MultipleLines ---
# ['No' 'Yes']
#
# --- OnlineSecurity ---
# ['No' 'Yes']
#
# --- OnlineBackup ---
# ['Yes' 'No']
#
# --- DeviceProtection ---
# ['No' 'Yes']
#
# --- TechSupport ---
# ['Yes' 'No']
#
# --- StreamingTV ---
# ['Yes' 'No']
#
# --- StreamingMovies ---
# ['No' 'Yes']

# %%
df['MultipleLines'] = df['MultipleLines'].replace({'No':0,'Yes':1})
df['OnlineSecurity'] = df['OnlineSecurity'].replace({'No':0,'Yes':1})
df['OnlineBackup'] = df['OnlineBackup'].replace({'No':0,'Yes':1})
df['DeviceProtection'] = df['DeviceProtection'].replace({'No':0,'Yes':1})
df['TechSupport'] = df['TechSupport'].replace({'No':0,'Yes':1})
df['StreamingTV'] = df['StreamingTV'].replace({'No':0,'Yes':1})
df['StreamingMovies'] = df['StreamingMovies'].replace({'No':0,'Yes':1})
df['Churn'] = df['Churn'].replace({'No':0,'Yes':1})
df['Partner'] = df['Partner'].replace({'No':0,'Yes':1})
df['Dependents'] = df['Dependents'].replace({'No':0,'Yes':1})
df['PhoneService'] = df['PhoneService'].replace({'No':0,'Yes':1})
df['PaperlessBilling'] = df['PaperlessBilling'].replace({'No':0,'Yes':1})

# Verify the changes by checking unique values in the modified columns
print("\nUnique values in modified columns:")
columns_to_verify = ['MultipleLines'] + internet_cols_to_clean
for col in columns_to_verify:
    print(f"\n--- {col} ---")
    print(df[col].unique())
# Out:
# Unique values in modified columns:
#
# --- MultipleLines ---
# [0 1]
#
# --- OnlineSecurity ---
# [0 1]
#
# --- OnlineBackup ---
# [1 0]
#
# --- DeviceProtection ---
# [0 1]
#
# --- TechSupport ---
# [1 0]
#
# --- StreamingTV ---
# [1 0]
#
# --- StreamingMovies ---
# [0 1]
# /tmp/ipython-input-633692988.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['MultipleLines'] = df['MultipleLines'].replace({'No':0,'Yes':1})
# /tmp/ipython-input-633692988.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %% [markdown]
# #📊 Carga y análisis

# %% [markdown]
# #📄Informe final
